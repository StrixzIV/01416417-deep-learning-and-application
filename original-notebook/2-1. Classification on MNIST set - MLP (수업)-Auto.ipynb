# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from tensorflow.keras import initializers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD
from IPython.display import Image
PATH = "/Users/User/Desktop/Deep learning codes/"

# %%
# minist dataset

Image(filename = PATH + "33.jpg")

# %%
Image(filename = PATH + "34.jpg")

# 28 x 28 = 784 image
# 0 ~ 9 digit recognition (10 classes)

# %%
# section 1
# Hyperparameters

learning_rate = 0.1
batch_size = 128
num_epochs = 10

# %%
# section 2
# Load the MNIST dataset and normalize the pixel values to be between 0 and 1

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# section 3
# Split the training set into a training set and a validation set with a ratio of 9:1 

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.1, random_state = 42)

# %%
# section 4
# Define a model architecture with hidden layer

input_shape = (28, 28)
num_classes = 10

# ?

# %%
# section 5
# print the model summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
# section 6
# Define loss

# loss_fn = ?

# %%
# section 7
# Define an optimizer

# optimizer = ?
# Out:
# C:\Users\User\anaconda3\envs\test_tf\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# section 8
# compile the model

# %%
# section 9
# train the model

#history = model.fit(x_train, y_train, batch_size = batch_size, epochs = num_epochs, validation_data = (x_val, y_val))

for epoch in range(num_epochs):
    print("epoch {}/{}".format(epoch + 1, num_epochs))
    history = model.fit(x_train, y_train, validation_data = (x_val, y_val), batch_size = batch_size)
    
    # print("Training loss: {:.4f}".format(history.history["loss"][-1]))
    # print("Training accuracy: {:.4f}".format(history.history["accuracy"][-1]))
    # print("Validation loss: {:.4f}".format(history.history["val_loss"][-1]))
    # print("Validation accuracy: {:.4f}".format(history.history["val_accuracy"][-1]))
# Out:
# epoch 1/10
# 422/422 [==============================] - 5s 5ms/step - loss: 0.5228 - accuracy: 0.8571 - val_loss: 0.3177 - val_accuracy: 0.9095
# epoch 2/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.2916 - accuracy: 0.9171 - val_loss: 0.2573 - val_accuracy: 0.9293
# epoch 3/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.2481 - accuracy: 0.9303 - val_loss: 0.2265 - val_accuracy: 0.9375
# epoch 4/10
# 422/422 [==============================] - 2s 6ms/step - loss: 0.2189 - accuracy: 0.9384 - val_loss: 0.2030 - val_accuracy: 0.9435
# epoch 5/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1969 - accuracy: 0.9445 - val_loss: 0.1899 - val_accuracy: 0.9465
# epoch 6/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1797 - accuracy: 0.9489 - val_loss: 0.1786 - val_accuracy: 0.9480
# epoch 7/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1660 - accuracy: 0.9534 - val_loss: 0.1650 - val_accuracy: 0.9513
# epoch 8/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1546 - accuracy: 0.9560 - val_loss: 0.1541 - val_accuracy: 0.9565
# epoch 9/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1451 - accuracy: 0.9586 - val_loss: 0.1455 - val_accuracy: 0.9597
# epoch 10/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1366 - accuracy: 0.9611 - val_loss: 0.1479 - val_accuracy: 0.9573

# %%
# section 10
# evaluate test accuracy

test_loss, test_acc = model.evaluate(x_test, y_test)
print('test_acc:', test_acc)
# Out:
#  25/313 [=>............................] - ETA: 1s - loss: 0.1385 - accuracy: 0.9538
