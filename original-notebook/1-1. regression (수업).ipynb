# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image
PATH = "/Users/User/Desktop/Deep learning codes/"

# %%
# dataset

Image(filename = PATH + "22.jpg")

# %%
# load data

xy = np.loadtxt('data-01-test-score.csv', delimiter = ',', dtype = np.float32)

x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

# make sure the shape and data are OK

print(x_data.shape, x_data)
print(y_data.shape, y_data)
# Out:
# (6, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]]
# (6, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]]

# %%
# Define the test data

x_test = np.array([[100, 70, 101]], dtype = np.float32)

# %%
# Define the model

# %%
# Compile the model

# %%
# Train the model

# %%
# Print the model's summary

# %%
# Print the weight (parameter) and bias of the model

# weights = model.get_weights()
# print(f'Weight: {weights[0]}, Bias: {weights[1]}')

# %%
# Make a prediction on the test data

# y_pred = model.predict(x_test)
# print(f'Predicted score: {y_pred[0][0]}')
